# %% [raw]
# ---
# title: "Quarto Basics"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %%
# Importing required libraries
#| echo: false
import pandas as pd
import matplotlib.pyplot as plt

# %%
#| label: Experiment with line
#| fig-cap: Just a line
plt.plot([1,2,3],[1,2,3])
plt.title("Line")
plt.show()
